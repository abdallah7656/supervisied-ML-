# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn import svm
from   sklearn.metrics import  accuracy_score ,confusion_matrix

# %%
# load the iris dataset 

iris = load_iris()

# %%
# store the feature matrix (X) and response vector (y) 
#iris
X = iris.data 
y = iris.target

# %%
#import train_test_split function
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=42)

# %%
C_ = 1000     # SVM regularization parameter
clf = svm.SVC( kernel='rbf',C=C_)
clf.fit(X_train,y_train)    #train the model using the training sets
# Out:
# SVC(C=1000)

# %%
y_pred = clf.predict(X_test) #test the model using the test sets
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
# SVC(C=1.0, kernel='rbf', degree=3, gamma='auto') --> Low Tolerant RBF Kernels

# SVC(C=1000.0,kernel='linear',degree=3,gamma='auto')-->High Tolerant linear Kernels

# %% [markdown]
# # reference
#
# https://scikit-learn.org/stable/modules/svm.html#classification
